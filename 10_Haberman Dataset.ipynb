# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

haberman=pd.read_csv('/Users/jayraj/Applied_AI_Course/Applied_ai_course/Datasets/haberman.csv')
df=haberman
df
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
print(df.shape)
# Out:
# (305, 4)

# %%
print(haberman.columns)
# Out:
# Index(['30', '64', '1', '1.1'], dtype='object')

# %%
header_list = ["Age", "Year", "positive_axillary_nodes", "survival_status"]
df = pd.read_csv("/Users/jayraj/Applied_AI_Course/Applied_ai_course/Datasets/haberman.csv", names=header_list)
print(df)
# Out:
#      Age  Year  positive_axillary_nodes  survival_status
# 0     30    64                        1                1
# 1     30    62                        3                1
# 2     30    65                        0                1
# 3     31    59                        2                1
# 4     31    65                        4                1
# ..   ...   ...                      ...              ...
# 301   75    62                        1                1
# 302   76    67                        0                1
# 303   77    65                        3                1
# 304   78    65                        1                2
# 305   83    58                        2                2
#
# [306 rows x 4 columns]

# %%
df['Year'][df['Age']==30]
# Out:
# 0    64
# 1    62
# 2    65
# Name: Year, dtype: int64

# %%
age_grouped_df= df.groupby("Age")
age_grouped_df.head(30)

for age, age_g in age_grouped_df:
    print(age)
    print(age_g)
# Out:
# 30
#    Age  Year  positive_axillary_nodes  survival_status
# 0   30    64                        1                1
# 1   30    62                        3                1
# 2   30    65                        0                1
# 31
#    Age  Year  positive_axillary_nodes  survival_status
# 3   31    59                        2                1
# 4   31    65                        4                1
# 33
#    Age  Year  positive_axillary_nodes  survival_status
# 5   33    58                       10                1
# 6   33    60                        0                1
# 34
#     Age  Year  positive_axillary_nodes  survival_status
# 7    34    59                        0                2
# 8    34    66                        9                2
# 9    34    58                       30                1
# 10   34    60                        1                1
# 11   34    61                       10                1
# 12   34    67                        7                1
# ...

# %%
# to check the number of rows and columns in a given dataset
df.shape
# Out:
# (306, 4)

# %%
# to check the number of columns
print(df.columns)
print("the number of features in the given dataset is", len(df.columns))
# Out:
# Index(['Age', 'Year', 'positive_axillary_nodes', 'survival_status'], dtype='object')
# the number of features in the given dataset is 4

# %%
print(df.loc[1:5])
print(df.iloc[1:5])
# Out:
#    Age  Year  positive_axillary_nodes  survival_status
# 1   30    62                        3                1
# 2   30    65                        0                1
# 3   31    59                        2                1
# 4   31    65                        4                1
# 5   33    58                       10                1
#    Age  Year  positive_axillary_nodes  survival_status
# 1   30    62                        3                1
# 2   30    65                        0                1
# 3   31    59                        2                1
# 4   31    65                        4                1

# %%
# to get information about the given data
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      306 non-null    int64
#  1   Year                     306 non-null    int64
#  2   positive_axillary_nodes  306 non-null    int64
#  3   survival_status          306 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB
# None

# %%
# to check the number of null values
df.isnull().sum()
# Out:
# Age                        0
# Year                       0
# positive_axillary_nodes    0
# survival_status            0
# dtype: int64

# %%
# to convert the survival status to categorical data
df['survival_status']=df['survival_status'].map({1:'yes', 2: 'no'})

# %%
# to print the first 5 rows and columns
print(df.head())
# Out:
#    Age  Year  positive_axillary_nodes survival_status
# 0   30    64                        1             yes
# 1   30    62                        3             yes
# 2   30    65                        0             yes
# 3   31    59                        2             yes
# 4   31    65                        4             yes

# %%
# to check the number of classes and their number
df['survival_status'].value_counts()
# Out:
# yes    225
# no      81
# Name: survival_status, dtype: int64

# %% [markdown]
# out of the 306 people in the given data, 225 people have survived 5 years or more after the operation and 81 people have died in five year after the operation.

# %% [markdown]
# Observation 1:
# 225 patients survived five years or longer
# 81 patients died in five year

# %%
plt.figure(figsize=(10,5))
df['survival_status'].value_counts().plot(kind='bar')
plt.xticks()
plt.ylabel('no. of datapoints')
plt.title('distribution of classes')
plt.show()

# %%
# to determine the percentage of distribution of classes
df["survival_status"].value_counts(1)
# Out:
# yes    0.735294
# no     0.264706
# Name: survival_status, dtype: float64

# %%
df['Age'].value_counts()
# Out:
# 52    14
# 54    13
# 50    12
# 47    11
# 53    11
# 43    11
# 57    11
# 49    10
# 65    10
# 55    10
# 38    10
# 41    10
# 42     9
# 45     9
# 61     9
# 59     8
# 63     8
# 56     7
# 58     7
# 62     7
# 48     7
# 46     7
# 44     7
# 70     7
# 34     7
# 51     6
# 67     6
# 39     6
# 37     6
# 60     6
# 66     5
# 64     5
# 69     4
# 72     4
# 30     3
# 40     3
# 31     2
# 68     2
# 36     2
# 35     2
# 33     2
# 73     2
# 74     2
# 71     1
# 75     1
# 76     1
# 77     1
# 78     1
# 83     1
# Name: Age, dtype: int64

# %%
plt.figure(figsize=(10,5))
df['Age'].value_counts().plot(kind='bar')
plt.xticks()
plt.ylabel('no. of datapoints')
plt.xlabel("Age")
plt.title('distribution of classes')
plt.show()

# %%
df['Year'].value_counts()
# Out:
# 58    36
# 64    31
# 63    30
# 65    28
# 60    28
# 66    28
# 59    27
# 61    26
# 67    25
# 62    23
# 68    13
# 69    11
# Name: Year, dtype: int64

# %%
# print the unique values of the class label column
print(list(df['survival_status'].unique()))
# Out:
# ['yes', 'no']

# %%
plt.figure(figsize=(10,5))
df['Year'].value_counts().plot(kind='bar')
plt.xticks()
plt.ylabel('no. of datapoints')
plt.xlabel("Age of patient")
plt.title('distribution of classes')
plt.show()

# %%
df['positive_axillary_nodes'].value_counts()
# Out:
# 0     136
# 1      41
# 3      20
# 2      20
# 4      13
# 7       7
# 6       7
# 8       7
# 9       6
# 5       6
# 13      5
# 14      4
# 11      4
# 22      3
# 19      3
# 23      3
# 15      3
# 10      3
# 20      2
# 12      2
# 21      1
# 52      1
# 30      1
# 16      1
# 24      1
# 46      1
# 18      1
# 35      1
# 17      1
# 25      1
# 28      1
# Name: positive_axillary_nodes, dtype: int64

# %%
plt.figure(figsize=(10,5))
df['positive_axillary_nodes'].value_counts().plot(kind='bar')
plt.xticks()
plt.ylabel('no. of datapoints')
plt.xlabel('positive_axillary_nodes')
plt.title('distribution of classes')
plt.show()

# %%
df.plot(kind='scatter', x='Year', y='survival_status')
plt.show()

# %%
plt.close()
sns.set_style('whitegrid')
sns.pairplot(df, hue='survival_status', palette="colorblind", height=3, diag_kind='hist')
sns.color_palette("bright")
plt.show()

# %%
sns.FacetGrid(df, hue='survival_status', palette="colorblind",height=4)\
   .map(sns.distplot, 'Age')\
   .add_legend()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df, hue='survival_status',height=4)\
   .map(sns.distplot, 'Year')\
   .add_legend()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df, hue='survival_status',height=6)\
   .map(sns.distplot, 'positive_axillary_nodes')\
   .add_legend()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# plotting distribution plot for all features
for idx, feature in enumerate(list(df.columns)[:-1]):
    fg = sns.FacetGrid(df, hue='survival_status', height=5)
    fg.map(sns.distplot, feature).add_legend()
    plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ## PDF & CDF plots for all features

# %%
# CDF - The cumulative distribution function (cdf) is the probability that 
# the variable takes a value less than or equal to x.

plt.figure(figsize=(20,5))
for idx, feature in enumerate(list(df.columns)[:-1]):
    
    plt.subplot(1, 3, idx+1)
    print("********* "+feature+" *********")
    
    counts, bin_edges = np.histogram(df[feature], bins=10, density=True)
    print("Bin Edges: {}".format(bin_edges))
    pdf = counts/sum(counts)
    print("PDF: {}".format(pdf))
    cdf = np.cumsum(pdf)
    print("CDF: {}".format(cdf))
    
    plt.plot(bin_edges[1:], pdf, bin_edges[1:], cdf)
    plt.xlabel(feature)
# Out:
# ********* Age *********
# Bin Edges: [30.  35.3 40.6 45.9 51.2 56.5 61.8 67.1 72.4 77.7 83. ]
# PDF: [0.05228758 0.08823529 0.1503268  0.17320261 0.17973856 0.13398693
#  0.13398693 0.05882353 0.02287582 0.00653595]
# CDF: [0.05228758 0.14052288 0.29084967 0.46405229 0.64379085 0.77777778
#  0.91176471 0.97058824 0.99346405 1.        ]
# ********* Year *********
# Bin Edges: [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]
# PDF: [0.20588235 0.09150327 0.08496732 0.0751634  0.09803922 0.10130719
#  0.09150327 0.09150327 0.08169935 0.07843137]
# CDF: [0.20588235 0.29738562 0.38235294 0.45751634 0.55555556 0.65686275
#  0.74836601 0.83986928 0.92156863 1.        ]
# ********* positive_axillary_nodes *********
# Bin Edges: [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]
# PDF: [0.77124183 0.09803922 0.05882353 0.02614379 0.02941176 0.00653595
#  0.00326797 0.         0.00326797 0.00326797]
# CDF: [0.77124183 0.86928105 0.92810458 0.95424837 0.98366013 0.99019608
# ...

# %% [markdown]
# ## PDF & CDF plots for all features based on class label

# %% [markdown]
# Separate the class labels based on their similar values

# %%
survived=df[df['survival_status']=='yes']
survived.head()
# Out:
#    Age  Year  positive_axillary_nodes survival_status
# 0   30    64                        1             yes
# 1   30    62                        3             yes
# 2   30    65                        0             yes
# 3   31    59                        2             yes
# 4   31    65                        4             yes

# %%
not_survived=df[df["survival_status"]=='no']
not_survived.head()
# Out:
#     Age  Year  positive_axillary_nodes survival_status
# 7    34    59                        0              no
# 8    34    66                        9              no
# 24   38    69                       21              no
# 34   39    66                        0              no
# 43   41    60                       23              no

# %% [markdown]
# Plotting of CDF and PDF for separated class labels

# %%
# CDF - The cumulative distribution function (cdf) is the probability that 
# the variable takes a value less than or equal to x.

plt.figure(figsize=(20,5))
for idx, feature in enumerate(list(survived.columns)[:-1]):
    
    plt.subplot(1, 3, idx+1)
    print("********* "+feature+" *********")
    
    counts, bin_edges = np.histogram(survived[feature], bins=10, density=True)
    print("Bin Edges: {}".format(bin_edges))
    pdf = counts/sum(counts)
    print("PDF: {}".format(pdf))
    cdf = np.cumsum(pdf)
    print("CDF: {}".format(cdf))
    
    plt.plot(bin_edges[1:], pdf, bin_edges[1:], cdf)
    plt.xlabel(feature)
# Out:
# ********* Age *********
# Bin Edges: [30.  34.7 39.4 44.1 48.8 53.5 58.2 62.9 67.6 72.3 77. ]
# PDF: [0.05333333 0.10666667 0.12444444 0.09333333 0.16444444 0.16444444
#  0.09333333 0.11111111 0.06222222 0.02666667]
# CDF: [0.05333333 0.16       0.28444444 0.37777778 0.54222222 0.70666667
#  0.8        0.91111111 0.97333333 1.        ]
# ********* Year *********
# Bin Edges: [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]
# PDF: [0.18666667 0.10666667 0.10222222 0.07111111 0.09777778 0.10222222
#  0.06666667 0.09777778 0.09333333 0.07555556]
# CDF: [0.18666667 0.29333333 0.39555556 0.46666667 0.56444444 0.66666667
#  0.73333333 0.83111111 0.92444444 1.        ]
# ********* positive_axillary_nodes *********
# Bin Edges: [ 0.   4.6  9.2 13.8 18.4 23.  27.6 32.2 36.8 41.4 46. ]
# PDF: [0.83555556 0.08       0.02222222 0.02666667 0.01777778 0.00444444
#  0.00888889 0.         0.         0.00444444]
# CDF: [0.83555556 0.91555556 0.93777778 0.96444444 0.98222222 0.98666667
# ...

# %% [markdown]
# Observations
# 1 graph- 90% of the people have age less than 70
# 3 graph- 80% of the survived people have nodes less than 5

# %%
# CDF - The cumulative distribution function (cdf) is the probability that 
# the variable takes a value less than or equal to x.

plt.figure(figsize=(20,5))
for idx, feature in enumerate(list(not_survived.columns)[:-1]):
    
    plt.subplot(1, 3, idx+1)
    print("********* "+feature+" *********")
    
    counts, bin_edges = np.histogram(not_survived[feature], bins=10, density=True)
    print("Bin Edges: {}".format(bin_edges))
    pdf = counts/sum(counts)
    print("PDF: {}".format(pdf))
    cdf = np.cumsum(pdf)
    print("CDF: {}".format(cdf))
    
    plt.plot(bin_edges[1:], pdf, bin_edges[1:], cdf)
    plt.xlabel(feature)
# Out:
# ********* Age *********
# Bin Edges: [34.  38.9 43.8 48.7 53.6 58.5 63.4 68.3 73.2 78.1 83. ]
# PDF: [0.03703704 0.12345679 0.19753086 0.19753086 0.13580247 0.12345679
#  0.09876543 0.04938272 0.02469136 0.01234568]
# CDF: [0.03703704 0.16049383 0.35802469 0.55555556 0.69135802 0.81481481
#  0.91358025 0.96296296 0.98765432 1.        ]
# ********* Year *********
# Bin Edges: [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]
# PDF: [0.25925926 0.04938272 0.03703704 0.08641975 0.09876543 0.09876543
#  0.16049383 0.07407407 0.04938272 0.08641975]
# CDF: [0.25925926 0.30864198 0.34567901 0.43209877 0.5308642  0.62962963
#  0.79012346 0.86419753 0.91358025 1.        ]
# ********* positive_axillary_nodes *********
# Bin Edges: [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]
# PDF: [0.56790123 0.14814815 0.13580247 0.04938272 0.07407407 0.
#  0.01234568 0.         0.         0.01234568]
# CDF: [0.56790123 0.71604938 0.85185185 0.90123457 0.97530864 0.97530864
# ...

# %% [markdown]
# Estimator Cumulative Distributive Function plot for feature variable i.e. Positive_Axillary_Nodes

# %%
def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""
    # Number of data points: n
    n = len(data)
    # x-data for the ECDF: x
    x = np.sort(data)
    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n
    return x, y

# Compute ECDF for Postive_Axillary_Nodes data: x_vers, y_vers
x_vers, y_vers = ecdf(df['positive_axillary_nodes'])


# Generate plot
plt.plot(x_vers, y_vers, marker='.', linestyle='none')
# Label the axes
plt.xlabel('positive_axillary_nodes')
plt.ylabel('ECDF')
# Display the plot
plt.show()

# %% [markdown]
# ## Box plot for all features

# %%
# box plot for all independent variables

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for idx, feature in enumerate(list(df.columns)[:-1]):
    sns.boxplot( x='survival_status', y = feature, 
                 data=df, ax=axes[idx])
plt.show()

# %% [markdown]
# ## Violin plots for all features

# %%
# violin plot for all independent variables

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for idx, feature in enumerate(list(df.columns)[:-1]):
    sns.violinplot( x='survival_status', y=feature, 
                    data=df, ax=axes[idx])
plt.show()

# %% [markdown]
# ## Strip plot 1-D Scatter plot

# %%
# strip plot for all independent variables
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for idx, feature in enumerate(list(df.columns)[:-1]):
    sns.stripplot( x='survival_status', y=feature, 
                   data=df, ax=axes[idx], jitter=True)
plt.show()

# %% [markdown]
# ## Bee swarm plots
#
# A Beeswarm/Swarm plot is a two-dimensional visualization technique where data points are plotted relative to a fixed reference axis so that no two data points overlap.
# The Beeswarm plot is a useful technique when we wish to see not only the measured values of interest for each data point, but also the distribution of these values.
# The swarm plots are more detailed than histogram, cause all data is displayed.

# %%
# swarm plot for all independent variables
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for idx, feature in enumerate(list(df.columns)[:-1]):
    sns.swarmplot( x='survival_status', y=feature, 
                   data=df, ax=axes[idx])
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 11.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 49.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Scatter plot

# %%
# 2-D Scatter plots are used to visualize relationship between two variables only
# Here 'sns' corresponds to seaborn.
# 2-D Scatter plot with color-coding for each Survival type/class.
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="survival_status",palette="colorblind", size=4) \
   .map(plt.scatter, "Age", "positive_axillary_nodes") \
   .add_legend();
plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rp/8sq6h5px3mg90rq964p20c_00000gn/T/ipykernel_2818/209952516.py in <module>
#       2 # Here 'sns' corresponds to seaborn.
#       3 # 2-D Scatter plot with color-coding for each Survival type/class.
# ----> 4 sns.set_style("whitegrid");
#       5 sns.FacetGrid(df, hue="survival_status",palette="colorblind", size=4) \
#       6    .map(plt.scatter, "Age", "positive_axillary_nodes") \
#
# NameError: name 'sns' is not defined

# %% [markdown]
# ## Pair plot

# %%
# after we have made the categorical variable 'Survival_Status' as of type 'category', 
# the default sns pairplot won't show that feature now.
sns.pairplot(df)

# %%
# plot the data points using color encoding, based on the class label.
sns.pairplot(df, hue = 'survival_status', height = 3)
plt.show()

# %%
# to convert the survival status to numerical data
df['survival_status']=df['survival_status'].map({'yes':1, 'no':2})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      306 non-null    int64
#  1   Year                     306 non-null    int64
#  2   positive_axillary_nodes  306 non-null    int64
#  3   survival_status          306 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
print(list(df['survival_status'].unique()))
# Out:
# [1, 2]

# %%
# generate correlation matrix
df.corr() # for this to work, all columns should be numerical
# Out:
#                               Age      Year  positive_axillary_nodes  \
# Age                      1.000000  0.089529                -0.063176
# Year                     0.089529  1.000000                -0.003764
# positive_axillary_nodes -0.063176 -0.003764                 1.000000
# survival_status          0.067950 -0.004768                 0.286768
#
#                          survival_status
# Age                             0.067950
# Year                           -0.004768
# positive_axillary_nodes         0.286768
# survival_status                 1.000000

# %% [markdown]
# ## Correlation heatmap

# %%
# look at the heatmap of the correlation matrix of our dataset
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Correlation of independent variables against the class label

# %%
df.corr()['survival_status'] # numerical correlation matrix
# Out:
# Age                        0.067950
# Year                      -0.004768
# positive_axillary_nodes    0.286768
# survival_status            1.000000
# Name: survival_status, dtype: float64
