# %%
import pandas as pd
dataset=pd.read_csv('nyc_weather.csv')
dataset
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
dataset[["Temperature", 'DewPoint']][dataset['Events']=='Rain']
# Out:
#     Temperature  DewPoint
# 8            44        38
# 9            50        46
# 15           47        37
# 26           41        22

# %%
dataset[dataset.Temperature==dataset.Temperature.max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
raindaydata=dataset[dataset['Events']=='Rain']
raindaydata
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 9              109
# 15             340
# 26             311

# %%
# to check the highest temperature in the month

print("the max temp in the month of january is = ", dataset['Temperature'].max())
print(dataset["Temperature"].min())
print(dataset['Temperature'].std())
# Out:
# the max temp in the month of january is =  50
# 20
# 7.639315400279416

# %%
# to find the dates on which the rain happened
dataset['EST'][dataset['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
dataset['EST'][dataset['VisibilityMiles']==10]
# Out:
# 0      1/1/2016
# 1      1/2/2016
# 2      1/3/2016
# 3      1/4/2016
# 4      1/5/2016
# 5      1/6/2016
# 6      1/7/2016
# 7      1/8/2016
# 10    1/11/2016
# 11    1/12/2016
# 12    1/13/2016
# 13    1/14/2016
# 18    1/19/2016
# 19    1/20/2016
# 20    1/21/2016
# 24    1/25/2016
# 25    1/26/2016
# 26    1/27/2016
# 27    1/28/2016
# 28    1/29/2016
# 29    1/30/2016
# 30    1/31/2016
# Name: EST, dtype: object

# %% [markdown]
# ## Pandas on a dataset

# %%
import pandas as pd

df=pd.read_csv('/Users/jayraj/Applied_AI_Course/Applied_ai_course/Datasets/Pandas_Practice_Police_Dataset.csv')

# %%
df.head(6)
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
# 5  2005-03-23     09:45          NaN             M          1982.0
#
#    driver_age driver_race                   violation_raw  violation  \
# 0        20.0       White                        Speeding   Speeding
# 1        40.0       White                        Speeding   Speeding
# 2        33.0       White                        Speeding   Speeding
# 3        19.0       White                Call for Service      Other
# 4        21.0       White                        Speeding   Speeding
# 5        23.0       Black  Equipment/Inspection Violation  Equipment
#
# ...

# %%
df.tail()
# Out:
#        stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 91736 2015-12-31  20:27:00          NaN             M          1986.0
# 91737 2015-12-31  20:35:00          NaN             F          1982.0
# 91738 2015-12-31  20:45:00          NaN             M          1992.0
# 91739 2015-12-31  21:42:00          NaN             M          1993.0
# 91740 2015-12-31  22:46:00          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 91736        29.0       White                        Speeding
# 91737        33.0       White  Equipment/Inspection Violation
# 91738        23.0       White         Other Traffic Violation
# 91739        22.0       White                        Speeding
# 91740        56.0    Hispanic                        Speeding
#
#               violation  search_conducted search_type stop_outcome  \
# 91736          Speeding             False         NaN      Warning
# ...

# %%
import datetime as dt
df['stop_date']=pd.to_datetime(df['stop_date'])
df['stop_time']=pd.to_datetime(df['stop_time'],format='%H:%M:%S')

# %%
df.shape
# Out:
# (91741, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  datetime64[ns]
#  1   stop_time           91741 non-null  datetime64[ns]
#  2   county_name         0 non-null      float64
#  3   driver_gender       86406 non-null  object
#  4   driver_age_raw      86414 non-null  float64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86408 non-null  object
#  7   violation_raw       86408 non-null  object
#  8   violation           86408 non-null  object
#  9   search_conducted    91741 non-null  bool
#  10  search_type         3196 non-null   object
#  11  stop_outcome        86408 non-null  object
#  12  is_arrested         86408 non-null  object
#  13  stop_duration       86408 non-null  object
#  14  drugs_related_stop  91741 non-null  bool
# ...

# %%
df.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
df.drop(['county_name'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    stop_date           stop_time driver_gender  driver_age_raw  driver_age  \
# 0 2005-01-02 1900-01-01 01:55:00             M          1985.0        20.0
# 1 2005-01-18 1900-01-01 08:15:00             M          1965.0        40.0
# 2 2005-01-23 1900-01-01 23:15:00             M          1972.0        33.0
# 3 2005-02-20 1900-01-01 17:15:00             M          1986.0        19.0
# 4 2005-03-14 1900-01-01 10:00:00             F          1984.0        21.0
#
#   driver_race     violation_raw violation  search_conducted search_type  \
# 0       White          Speeding  Speeding             False         NaN
# 1       White          Speeding  Speeding             False         NaN
# 2       White          Speeding  Speeding             False         NaN
# 3       White  Call for Service     Other             False         NaN
# 4       White          Speeding  Speeding             False         NaN
#
#     stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
df.describe()
# Out:
#        driver_age_raw    driver_age
# count    86414.000000  86120.000000
# mean      1970.491228     34.011333
# std        110.914909     12.738564
# min          0.000000     15.000000
# 25%       1967.000000     23.000000
# 50%       1980.000000     31.000000
# 75%       1987.000000     43.000000
# max       8801.000000     99.000000

# %%
df['stop_date'].value_counts()
df['driver_gender'].value_counts()
# Out:
# M    62895
# F    23511
# Name: driver_gender, dtype: int64

# %%
# Target's value counts to check the balance
df['drugs_related_stop'].value_counts()

# Imbalanced Dataset
# Out:
# False    90926
# True       815
# Name: drugs_related_stop, dtype: int64

# %% [markdown]
# # Fill in the empty values

# %%
df['driver_gender'].fillna(df['driver_gender'].mode, inplace=True)
df['driver_gender'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Sampling

# %%
df.sample(10)
# Out:
#        stop_date           stop_time  \
# 727   2005-10-28 1900-01-01 11:35:00
# 12830 2006-12-16 1900-01-01 15:00:00
# 16157 2007-04-14 1900-01-01 13:50:00
# 62847 2012-08-17 1900-01-01 01:00:00
# 21118 2007-10-26 1900-01-01 09:57:00
# 36220 2009-07-17 1900-01-01 20:36:00
# 17420 2007-05-29 1900-01-01 20:30:00
# 29479 2008-10-08 1900-01-01 11:35:00
# 57082 2012-02-24 1900-01-01 10:11:00
# 83462 2015-01-13 1900-01-01 22:44:00
#
#                                            driver_gender  driver_age_raw  \
# 727    <bound method Series.mode of 0        M\n1    ...             NaN
# 12830                                                  F          1986.0
# 16157                                                  M          1976.0
# 62847                                                  M          1993.0
# 21118                                                  M          1987.0
# 36220                                                  M          1963.0
# ...

# %%
df['driver_gender'].nunique()
# Out:
# 3

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'driver_gender', 'driver_age_raw',
#        'driver_age', 'driver_race', 'violation_raw', 'violation',
#        'search_conducted', 'search_type', 'stop_outcome', 'is_arrested',
#        'stop_duration', 'drugs_related_stop'],
#       dtype='object')

# %%
df.nsmallest(5, 'driver_age_raw' )
# Out:
#      stop_date           stop_time driver_gender  driver_age_raw  driver_age  \
# 146 2005-10-05 1900-01-01 08:50:00             M             0.0         NaN
# 281 2005-10-10 1900-01-01 12:05:00             F             0.0         NaN
# 331 2005-10-12 1900-01-01 07:50:00             M             0.0         NaN
# 455 2005-10-18 1900-01-01 18:30:00             F             0.0         NaN
# 748 2005-10-29 1900-01-01 07:00:00             M             0.0         NaN
#
#     driver_race             violation_raw         violation  search_conducted  \
# 146       White   Other Traffic Violation  Moving violation             False
# 281       White   Other Traffic Violation  Moving violation             False
# 331       White  Motorist Assist/Courtesy             Other             False
# 455       White                  Speeding          Speeding             False
# 748       Black   Other Traffic Violation  Moving violation             False
#
# ...

# %%
df.nlargest(5, 'driver_age_raw')
# Out:
#        stop_date           stop_time driver_gender  driver_age_raw  \
# 17964 2007-06-17 1900-01-01 09:55:00             M          8801.0
# 37779 2009-10-10 1900-01-01 08:23:00             F          2919.0
# 66876 2013-02-04 1900-01-01 08:31:00             M          2013.0
# 56377 2012-02-05 1900-01-01 13:54:00             M          2011.0
# 37738 2009-10-07 1900-01-01 21:15:00             M          2009.0
#
#        driver_age driver_race                   violation_raw  \
# 17964         NaN       White                        Speeding
# 37779         NaN       White                        Speeding
# 66876         NaN       White          Registration Violation
# 56377         NaN       White  Special Detail/Directed Patrol
# 37738         NaN    Hispanic                        Speeding
#
#                  violation  search_conducted     search_type stop_outcome  \
# 17964             Speeding             False             NaN     Citation
# ...

# %% [markdown]
# # groupby()

# %%
df.groupby('driver_gender').get_group('M')
# Out:
#        stop_date           stop_time driver_gender  driver_age_raw  \
# 0     2005-01-02 1900-01-01 01:55:00             M          1985.0
# 1     2005-01-18 1900-01-01 08:15:00             M          1965.0
# 2     2005-01-23 1900-01-01 23:15:00             M          1972.0
# 3     2005-02-20 1900-01-01 17:15:00             M          1986.0
# 5     2005-03-23 1900-01-01 09:45:00             M          1982.0
# ...          ...                 ...           ...             ...
# 91735 2015-12-31 1900-01-01 20:25:00             M          1992.0
# 91736 2015-12-31 1900-01-01 20:27:00             M          1986.0
# 91738 2015-12-31 1900-01-01 20:45:00             M          1992.0
# 91739 2015-12-31 1900-01-01 21:42:00             M          1993.0
# 91740 2015-12-31 1900-01-01 22:46:00             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 0            20.0       White                        Speeding
# ...

# %% [markdown]
# # loc and iloc

# %%
df.loc[:5,['driver_gender', 'driver_age']]
# Out:
#   driver_gender  driver_age
# 0             M        20.0
# 1             M        40.0
# 2             M        33.0
# 3             M        19.0
# 4             F        21.0
# 5             M        23.0

# %%
df.loc[(df.driver_gender=='M') & (df.driver_age==40)]
# Out:
#        stop_date           stop_time driver_gender  driver_age_raw  \
# 1     2005-01-18 1900-01-01 08:15:00             M          1965.0
# 71    2005-10-02 1900-01-01 00:00:00             M          1965.0
# 99    2005-10-03 1900-01-01 08:37:00             M          1965.0
# 115   2005-10-04 1900-01-01 00:00:00             M          1965.0
# 160   2005-10-05 1900-01-01 19:15:00             M          1965.0
# ...          ...                 ...           ...             ...
# 91385 2015-12-12 1900-01-01 17:19:00             M          1975.0
# 91471 2015-12-16 1900-01-01 14:52:00             M          1975.0
# 91522 2015-12-19 1900-01-01 13:24:00             M          1975.0
# 91551 2015-12-21 1900-01-01 03:10:00             M          1975.0
# 91720 2015-12-31 1900-01-01 06:32:00             M          1975.0
#
#        driver_age driver_race                   violation_raw  \
# 1            40.0       White                        Speeding
# ...

# %%
df.iloc[0:5,0:4]
# Out:
#    stop_date           stop_time driver_gender  driver_age_raw
# 0 2005-01-02 1900-01-01 01:55:00             M          1985.0
# 1 2005-01-18 1900-01-01 08:15:00             M          1965.0
# 2 2005-01-23 1900-01-01 23:15:00             M          1972.0
# 3 2005-02-20 1900-01-01 17:15:00             M          1986.0
# 4 2005-03-14 1900-01-01 10:00:00             F          1984.0

# %%
df.sort_values(by='stop_date')
# Out:
#        stop_date           stop_time driver_gender  driver_age_raw  \
# 0     2005-01-02 1900-01-01 01:55:00             M          1985.0
# 1     2005-01-18 1900-01-01 08:15:00             M          1965.0
# 2     2005-01-23 1900-01-01 23:15:00             M          1972.0
# 3     2005-02-20 1900-01-01 17:15:00             M          1986.0
# 4     2005-03-14 1900-01-01 10:00:00             F          1984.0
# ...          ...                 ...           ...             ...
# 91718 2015-12-31 1900-01-01 00:01:00             M          1966.0
# 91717 2015-12-31 1900-01-01 00:00:00             F          1993.0
# 91739 2015-12-31 1900-01-01 21:42:00             M          1993.0
# 91727 2015-12-31 1900-01-01 09:17:00             F          1995.0
# 91740 2015-12-31 1900-01-01 22:46:00             M          1959.0
#
#        driver_age driver_race            violation_raw         violation  \
# 0            20.0       White                 Speeding          Speeding
# ...

# %% [markdown]
# # query()

# %%
df.query('1980 < driver_age_raw< 1986.0')
df.query("driver_race =='Hispanic' | violation == 'Call for Service'")
# Out:
#        stop_date           stop_time driver_gender  driver_age_raw  \
# 42    2005-10-01 1900-01-01 00:50:00             M          1977.0
# 198   2005-10-07 1900-01-01 00:50:00             M          1973.0
# 320   2005-10-11 1900-01-01 21:55:00             M          1977.0
# 339   2005-10-12 1900-01-01 20:30:00             M          1987.0
# 340   2005-10-12 1900-01-01 20:30:00             M          1987.0
# ...          ...                 ...           ...             ...
# 91723 2015-12-31 1900-01-01 07:14:00             M          1978.0
# 91728 2015-12-31 1900-01-01 13:50:00             F          1982.0
# 91730 2015-12-31 1900-01-01 15:36:00             F          1996.0
# 91735 2015-12-31 1900-01-01 20:25:00             M          1992.0
# 91740 2015-12-31 1900-01-01 22:46:00             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 42           28.0    Hispanic         Other Traffic Violation
# ...

# %% [markdown]
# # duplicated()

# %%
df.duplicated().sum()
# Out:
# 479

# %%
# dropping duplicates
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # get_dummies()

# %%
newdf=pd.get_dummies(df.driver_gender, prefix='driver_gender_').iloc[:,0:]
newdf
# Out:
#        driver_gender__<bound method Series.mode of 0        M\n1        M\n2        M\n3        M\n4        F\n        ..\n91736    M\n91737    F\n91738    M\n91739    M\n91740    M\nName: driver_gender, Length: 91741, dtype: object>  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 91736                                                  0
# 91737                                                  0
# 91738                                                  0
# 91739                                                  0
# 91740                                                  0
#
#        driver_gender__F  driver_gender__M
# 0                     0                 1
# ...

# %%
numerical_df=df.select_dtypes(include=[np.number])
numerical_df
# Out:
#        driver_age_raw  driver_age
# 0              1985.0        20.0
# 1              1965.0        40.0
# 2              1972.0        33.0
# 3              1986.0        19.0
# 4              1984.0        21.0
# ...               ...         ...
# 91736          1986.0        29.0
# 91737          1982.0        33.0
# 91738          1992.0        23.0
# 91739          1993.0        22.0
# 91740          1959.0        56.0
#
# [91262 rows x 2 columns]

# %%
categorical_df=df.select_dtypes(include='object')
categorical_df
# Out:
#       driver_gender driver_race                   violation_raw  \
# 0                 M       White                        Speeding
# 1                 M       White                        Speeding
# 2                 M       White                        Speeding
# 3                 M       White                Call for Service
# 4                 F       White                        Speeding
# ...             ...         ...                             ...
# 91736             M       White                        Speeding
# 91737             F       White  Equipment/Inspection Violation
# 91738             M       White         Other Traffic Violation
# 91739             M       White                        Speeding
# 91740             M    Hispanic                        Speeding
#
#               violation search_type   stop_outcome is_arrested stop_duration
# 0              Speeding         NaN       Citation       False      0-15 Min
# ...

# %%
combdf=pd.concat([numerical_df,categorical_df], axis=1)
combdf.head()
# Out:
#    driver_age_raw  driver_age driver_gender driver_race     violation_raw  \
# 0          1985.0        20.0             M       White          Speeding
# 1          1965.0        40.0             M       White          Speeding
# 2          1972.0        33.0             M       White          Speeding
# 3          1986.0        19.0             M       White  Call for Service
# 4          1984.0        21.0             F       White          Speeding
#
#   violation search_type   stop_outcome is_arrested stop_duration
# 0  Speeding         NaN       Citation       False      0-15 Min
# 1  Speeding         NaN       Citation       False      0-15 Min
# 2  Speeding         NaN       Citation       False      0-15 Min
# 3     Other         NaN  Arrest Driver        True     16-30 Min
# 4  Speeding         NaN       Citation       False      0-15 Min

# %% [markdown]
# # apply()

# %%
def currentage(dob):
    return (2022-dob)

# %%
df['driver_age_raw']=df['driver_age_raw'].apply(currentage)
df
# Out:
#        driver_age_raw  driver_age driver_gender driver_race  \
# 0                37.0        20.0             M       White
# 1                57.0        40.0             M       White
# 2                50.0        33.0             M       White
# 3                36.0        19.0             M       White
# 4                38.0        21.0             F       White
# ...               ...         ...           ...         ...
# 91736            36.0        29.0             M       White
# 91737            40.0        33.0             F       White
# 91738            30.0        23.0             M       White
# 91739            29.0        22.0             M       White
# 91740            63.0        56.0             M    Hispanic
#
#                         violation_raw         violation search_type  \
# 0                            Speeding          Speeding         NaN
# 1                            Speeding          Speeding         NaN
# ...

# %%
df.driver_age_qcut=pd.qcut(df['driver_age_raw'],q=5)
df.driver_age_qcut.value_counts()
# Out:
# (-6779.001, 34.0]    18638
# (39.0, 47.0]         17646
# (34.0, 39.0]         16773
# (47.0, 58.0]         16577
# (58.0, 2022.0]       16511
# Name: driver_age_raw, dtype: int64
